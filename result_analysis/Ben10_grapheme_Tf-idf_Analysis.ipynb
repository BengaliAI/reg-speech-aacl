# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount = True)
# Out:
# Mounted at /content/drive/

# %%
# !pip install jiwer
import os
import glob
import pandas as pd
import os
# from jiwer import wer,cer
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_colwidth', 0)

# %% [markdown]
# # TF-IDF calculation from Graphemes

# %%
# !pip install indicparser
# Out:
# Collecting indicparser
#   Downloading indicparser-0.1.0-py3-none-any.whl.metadata (5.6 kB)
# Downloading indicparser-0.1.0-py3-none-any.whl (7.4 kB)
# Installing collected packages: indicparser
# Successfully installed indicparser-0.1.0

# %%
test_df = pd.read_excel('/content/drive/MyDrive/local_speech/others/IUT_bhasha_bichitra/orig_iut_folds/fix_dataset/final/test/test.xlsx')
test_df
# Out:
#                     file_name           External_ID  district  \
# 0     test_barishal (1).wav    rec_21_audio_36.wav   barishal
# 1     test_barishal (10).wav   rec_21_audio_45.wav   barishal
# 2     test_barishal (100).wav  rec_24_audio_10.wav   barishal
# 3     test_barishal (101).wav  rec_24_audio_11.wav   barishal
# 4     test_barishal (102).wav  rec_24_audio_12.wav   barishal
# ...                       ...                  ...        ...
# 1677  test_tangail (95).wav    rec_39_audio_97.wav   tangail
# 1678  test_tangail (96).wav    rec_39_audio_98.wav   tangail
# 1679  test_tangail (97).wav    rec_39_audio_99.wav   tangail
# 1680  test_tangail (98).wav    rec_39_audio_100.wav  tangail
# 1681  test_tangail (99).wav    rec_39_audio_101.wav  tangail
#
#                                                                                                                                                                                                                                                                                                                                          transcriptions  \
# 0     তিন গাছ তিন গাছ ছয় গাছ দেবে। তুই আয় এই জাগা <> মুই বাত খাই খাওয়া অইয়া গ্যাছে। হাজা-গাজায় জম্মের পডু ব্যাডা, এট্টু মেহেদী, এট্টু লেবেস্টিক, এট্টু আইবুরু দেলে হেয়ার আর পিছ ছাড়ে না
# 1     গরম লাগে <> কী আছে? কই দেহি। ও পড়বে হোনেন না? ও দেইক্কা মনে অয় ই করছে। না এতে গরম লাগে তো, হাত <> দেয় নাই, ইদের সময় কিনছি না, কাইলগো ওই পোলায় হেই রাত্তিরে বাইর কইররা পড়াই দেছে <>
# 2     চেড়তে চেড়তে আগা বাইরাইয়া যায়। গত বছছর যহন এতো গাছ এই যে লেবারি করলাম এই গাছ, বড় বড় গাছ, যত বড় গাছ অউক <> হেই গাছে ওটছো?
# 3     ওরে আর, ওয়া তো যেকালে পারছো হেইকালে গাছে ওটছো <> কাম করা ভালো, এহন এই যে কিনছি এয়ারও কারন আছে, হ চলান-মলান লইয়া
# 4     মোর এট্টা ইসাব, কী? চা আর খামু না অনেক খাইছি। বোজ্জো? গাছের কাম যত দিকদা বাইরাইয়া অন্য কিছু করার চিন্তা আছে। হুম? এই জগতেইত্তা বাইরাইয়া অন্য কিছু করার চিন্তা আছে। হ, হ, অতোডু সময় কইরা-ঠইরা কিছু জোগাইতারলে হেইপর আর, এই জেন্যে এই গাছ কিনছি এহন ধরেন বেইচ্চা-বুইচ্চা, বেইচ্চা-বুইচ্চা জোগার কইরা জোগাড় করতে, আর ওই টাহা লাব, ওই লাবের টাহাইদ্দা
# ...                                                                                                                                                                                                                                                                                                                                                 ...
# 1677  সো ছবিটা আসলে দেখলে মানে ভাল্লাগবো অনেক। তারপরে আমি যেই মুভিডা শেয়ার করমু, সেইডা হইছে সাভারিয়া। এইডা দুই হাজার সাতের ছবি। এই গানগুলা আমি শুনছিলাম কিন্তু এর এই ছবিডা আমার কহোনোই আর কি দেহা
# 1678  পরে ইদানীং আমার কেমনে জানি মনে অইলো যে এই ছবিডা দ্যাহি। এই ছবিডা দ্যাহা অয় নাই। পরে এই ছবিডা মানে ডাউনলোড কইরা দেখতে দ্যাহা শুরু করলাম। দুই হাজার সাত সালের ছবি এইডা অইছে এই দেবদাসের যে ডিরেক্টর আছে, পদ্মাবতের যে ডিরেক্টর আছে, এ
# 1679  বলিউডের অন্যতম এক প্রভাবশালী ডিরেক্টর সঞ্জয় লীলা বানসালি, তার তৈরি। আর রনবীর কাপুর তহন, রনবীর কাপুরের ওইডা প্রথম ছবি। আর ছবিতে সালমান খান, সোনাম কাপুর, রাণী মুখার্জিও আছে। মেইন ক্যারেক্টার আছিলো এই চারজনেই।
# 1680  <> মুটামুটি এই চারজন বাদে আর কেউ নেই। আর এই ছবিতে আরেকটা বিষয় অইছে, এই ছবিতে আসলে মানুষ তেমন নাই ই। খুব অল্প মানুষ নিয়ে এই ছবিডা মানে মেক করা অইছে। আপনি পুরা ছবি দেখলেও মানে হাতেগোণা মানে দশজনেরও মনে অয় কম মানুষ নিয়া এই ছবিডা বানানো।
# 1681  এই ছবির শুরুতে দ্যাহা যায় যে, রাণী মুখার্জি থাকে। সে একটা কাল্পনিক শহরে থাকে। সে ওই জাগার এক প্রোস্টিটিউট আর কি কিন্তু ওই শহরে একদিন রনবীর কাপুর আসে। রনবীর কাপুর আহে। ওই সিনেমায় যা অর নাম থাকে রাজ।
#
#      Split                  annotator
# 0     Test  nahar2709marzan@gmail.com
# 1     Test  nahar2709marzan@gmail.com
# 2     Test  nahar2709marzan@gmail.com
# 3     Test  nahar2709marzan@gmail.com
# 4     Test  nahar2709marzan@gmail.com
# ...    ...                        ...
# 1677  Test  zubaer71.bd@gmail.com
# 1678  Test  zubaer71.bd@gmail.com
# 1679  Test  zubaer71.bd@gmail.com
# 1680  Test  zubaer71.bd@gmail.com
# 1681  Test  zubaer71.bd@gmail.com
#
# [1682 rows x 6 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from indicparser import graphemeParser

gp = graphemeParser("bangla")

bangla_stopwords = [
    'অতএব', 'অথচ', 'অথবা', 'অনুযায়ী', 'অনেক', 'অনেকে', 'অনেকেই', 'অন্তত', 'অন্য', 'অবধি',
    'অবশ্য', 'অর্থাত', 'আই', 'আগামী', 'আগে', 'আগেই', 'আছে', 'আজ', 'আদ্যভাগে', 'আপনার',
    'আপনি', 'আবার', 'আমরা', 'আমাকে', 'আমাদের', 'আমার', 'আমি', 'আর', 'আরও', 'ই', 'ইত্যাদি',
    'ইহা', 'উচিত', 'উত্তর', 'উনি', 'উপর', 'উপরে', 'এ', 'এঁদের', 'এঁরা', 'এই', 'একই', 'একটি',
    'একবার', 'একে', 'এক্', 'এখন', 'এখনও', 'এখানে', 'এখানেই', 'এটা', 'এটাই', 'এটি', 'এত',
    'এতটাই', 'এতে', 'এদের', 'এব', 'এবং', 'এবার', 'এমন', 'এমনকী', 'এমনি', 'এর', 'এরা', 'এল',
    'এস', 'এতে', 'ঐ', 'ও', 'ওঁদের', 'ওঁর', 'ওঁরা', 'ওই', 'ওকে', 'ওখানে', 'ওদের', 'ওর', 'ওরা',
    'কখনও', 'কত', 'কবে', 'কমনে', 'কয়েক', 'কয়েকটি', 'করছে', 'করছেন', 'করতে', 'করবে', 'করবেন',
    'করলে', 'করলেন', 'করা', 'করাই', 'করায়', 'করার', 'করি', 'করিতে', 'করিয়া', 'করিয়ে', 'করে',
    'করেই', 'করেছিলেন', 'করেছে', 'করেছেন', 'করেন', 'কাউকে', 'কাছ', 'কাছে', 'কাজ', 'কাজে',
    'কারও', 'কারণ', 'কি', 'কিংবা', 'কিছু', 'কিছুই', 'কিন্তু', 'কী', 'কে', 'কেউ', 'কেউই',
    'কেখা', 'কেন', 'কোটি', 'কোন', 'কোনও', 'কোনো', 'ক্ষেত্রে', 'কয়েক', 'খুব', 'গিয়ে', 'গিয়েছে',
    'গিয়ে', 'গুলি', 'গেছে', 'গেল', 'গেলে', 'গোটা', 'চলে', 'চান', 'চায়', 'চার', 'চালু', 'চেয়ে',
    'চেষ্টা', 'ছাড়া', 'ছাড়াও', 'ছিল', 'ছিলেন', 'জন', 'জনকে', 'জনের', 'জন্য', 'জন্যও', 'জে',
    'জানতে', 'জানা', 'জানানো', 'জানায়', 'জানিয়ে', 'জানিয়েছে', 'জে', 'টি', 'ঠিক', 'তখন', 'তত',
    'তথা', 'তবু', 'তবে', 'তা', 'তাঁকে', 'তাঁদের', 'তাঁর', 'তাঁরা', 'তাঁাহারা', 'তাই', 'তাও', 'তাকে',
    'তাতে', 'তাদের', 'তার', 'তারপর', 'তারা', 'তারৈ', 'তাহলে', 'তাহা', 'তাহাতে', 'তাহার', 'তিনঐ',
    'তিনি', 'তিনিও', 'তুমি', 'তুলে', 'তেমন', 'তো', 'তোমার', 'থাকবে', 'থাকবেন', 'থাকা', 'থাকায়',
    'থাকে', 'থাকেন', 'থেকে', 'থেকেই', 'থেকেও', 'দিকে', 'দিতে', 'দিন', 'দিয়ে', 'দিয়েছে', 'দিয়েছেন',
    'দিলেন', 'দু', 'দুই', 'দুটি', 'দুটো', 'দেওয়া', 'দেওয়ার', 'দেওয়া', 'দেখতে', 'দেখা', 'দেখে',
    'দেন', 'দেয়', 'দ্বারা', 'ধরা', 'ধরে', 'ধামার', 'নতুন', 'নয়', 'না', 'নাই', 'নাকি', 'নাগাদ',
    'নানা', 'নিজে', 'নিজেই', 'নিজেদের', 'নিজের', 'নিতে', 'নিয়ে', 'নিয়ে', 'নেই', 'নেওয়া', 'নেওয়ার',
    'নেওয়া', 'নয়', 'পক্ষে', 'পর', 'পরে', 'পরেই', 'পরেও', 'পর্যন্ত', 'পাওয়া', 'পাচ', 'পারি',
    'পারে', 'পারেন', 'পি', 'পেয়ে', 'পেয়্র্', 'প্রতি', 'প্রথম', 'প্রভৃতি', 'প্রযন্ত', 'প্রায়',
    'প্রায়', 'ফলে', 'ফিরে', 'ফের', 'বক্তব্য', 'বদলে', 'বন', 'বরং', 'বলতে', 'বলল', 'বললেন', 'বলা',
    'বলে', 'বলেছেন', 'বলেন', 'বসে', 'বহু', 'বা', 'বাদে', 'বার', 'বি', 'বিনা', 'বিভিন্ন', 'বিশেষ',
    'বিষয়টি', 'বেশ', 'বেশি', 'ব্যবহার', 'ব্যাপারে', 'ভাবে', 'ভাবেই', 'মতো', 'মতোই', 'মধ্যে',
    'মধ্যে', 'মধ্যেই', 'মধ্যেও', 'মনে', 'মাত্র', 'মাধ্যমে', 'মোট', 'মোটেই', 'যখন', 'যত',
    'যতটা', 'যথেষ্ট', 'যদি', 'যদিও', 'যা', 'যাঁর', 'যাঁরা', 'যাওয়া', 'যাওয়ার', 'যাওয়া',
    'যাকে', 'যাচ্ছে', 'যাতে', 'যাদের', 'যান', 'যাবে', 'যায়', 'যার', 'যারা', 'যিনি', 'যে',
    'যেখানে', 'যেতে', 'যেন', 'যেমন', 'র', 'রকম', 'রয়েছে', 'রাখা', 'রেখে', 'লক্ষ', 'শুধু',
    'শুরু', 'সঙ্গে', 'সঙ্গেও', 'সব', 'সবার', 'সমস্ত', 'সম্প্রতি', 'সহ', 'সহিত', 'সাধারণ', 'সামনে',
    'সি', 'সুতরাং', 'সে', 'সেই', 'সেখান', 'সেখানে', 'সেটা', 'সেটাই', 'সেটাও', 'সেটি', 'স্পষ্ট',
    'স্বয়ং', 'হইতে', 'হইবে', 'হইয়া', 'হওয়া', 'হওয়ায়', 'হওয়ার', 'হচ্ছে', 'হত', 'হতে',
    'হতেই', 'হন', 'হবে', 'হবেন', 'হয়', 'হয়তো', 'হয়নি', 'হয়ে', 'হয়েই', 'হয়েছিল', 'হয়েছে',
    'হয়েছেন', 'হল', 'হলে', 'হলেই', 'হলেও', 'হলো', 'হাজার', 'হিসাবে', 'হৈলে', 'হোক', 'হয়',
    'জন্যওজে', 'এসে', 'মধ্যভাগে', 'জ্নজন', 'প্রাথমিক', 'অনুসারে', 'অর্থাৎ',
    'মানে','একটা','সাথে','আসলে','এক','তারপরে','এইটা','মানুষ','ভালো','ছবিতে','হ্যা','হ্যাঁ','হয়ই','হয়ে','হয়তো','যায়','সময়',
    'দেয়','পায়','টাকা','পছন্দ','সুন্দর','বড়','আসে','একটু','কথা','এইরকম','জায়গায়','বাসায়','বুঝতে','চলতে'

]

def prepocess_text(text):
        words = re.findall(r"[\u0980-\u09FF\u200d]{1,}", text)
        filtered_words = [word for word in words if word not in bangla_stopwords]
        filtered_text = " ".join(filtered_words)
        return filtered_text

def extract_grapheme(text):
        graphemes = gp.process(text, merge_spaces=True)
        return graphemes

district_tfidf_results = {}

for district, group in test_df.groupby('district'):
    transcriptions = group['transcriptions'].astype(str)
    transcriptions = transcriptions.apply(prepocess_text)
    # grapheme_transcriptions = transcriptions.apply(extract_grapheme)
    vectorizer = TfidfVectorizer(
        tokenizer=extract_grapheme,
        token_pattern=None
    )
    tfidf_matrix = vectorizer.fit_transform(transcriptions)

    tfidf_df = pd.DataFrame(
        tfidf_matrix.toarray(),
        columns=vectorizer.get_feature_names_out(),
        index=group['file_name']
    )
    district_tfidf_results[district] = tfidf_df


district_tfidf_results['tangail']
# Out:
#                                          ং         ঃ         অ  অ্যা  \
# file_name
# test_tangail (1).wav    0.584070  0.000000  0.000000  0.000000  0.0
# test_tangail (10).wav   0.595698  0.000000  0.000000  0.000000  0.0
# test_tangail (100).wav  0.663496  0.000000  0.142306  0.047263  0.0
# test_tangail (101).wav  0.660005  0.000000  0.000000  0.070521  0.0
# test_tangail (102).wav  0.671284  0.000000  0.000000  0.179317  0.0
# ...                          ...       ...       ...       ...  ...
# test_tangail (95).wav   0.640783  0.000000  0.000000  0.000000  0.0
# test_tangail (96).wav   0.617342  0.087487  0.000000  0.125929  0.0
# test_tangail (97).wav   0.629586  0.000000  0.000000  0.039242  0.0
# test_tangail (98).wav   0.635838  0.000000  0.000000  0.211367  0.0
# test_tangail (99).wav   0.643277  0.000000  0.000000  0.050646  0.0
#
#                                আ         ই    ঈ         উ   উঁ  ...         ড়  \
# file_name                                                       ...
# test_tangail (1).wav    0.045235  0.064319  0.0  0.000000  0.0  ...  0.000000
# test_tangail (10).wav   0.000000  0.044514  0.0  0.163396  0.0  ...  0.000000
# test_tangail (100).wav  0.092985  0.132214  0.0  0.000000  0.0  ...  0.000000
# test_tangail (101).wav  0.034686  0.172618  0.0  0.000000  0.0  ...  0.082323
# test_tangail (102).wav  0.141114  0.100325  0.0  0.000000  0.0  ...  0.000000
# ...                          ...       ...  ...       ...  ...  ...       ...
# test_tangail (95).wav   0.000000  0.186212  0.0  0.000000  0.0  ...  0.000000
# test_tangail (96).wav   0.000000  0.146782  0.0  0.053879  0.0  ...  0.000000
# test_tangail (97).wav   0.038602  0.082331  0.0  0.050368  0.0  ...  0.000000
# test_tangail (98).wav   0.051980  0.073910  0.0  0.000000  0.0  ...  0.000000
# test_tangail (99).wav   0.049820  0.000000  0.0  0.065007  0.0  ...  0.000000
#
#                               ড়া   ড়ি   ড়ে         য়        য়া   য়ি   য়ী  \
# file_name
# test_tangail (1).wav    0.000000  0.0  0.0  0.000000  0.000000  0.0  0.0
# test_tangail (10).wav   0.000000  0.0  0.0  0.000000  0.064179  0.0  0.0
# test_tangail (100).wav  0.000000  0.0  0.0  0.159775  0.095311  0.0  0.0
# test_tangail (101).wav  0.000000  0.0  0.0  0.039734  0.142214  0.0  0.0
# test_tangail (102).wav  0.068227  0.0  0.0  0.040413  0.000000  0.0  0.0
# ...                          ...  ...  ...       ...       ...  ...  ...
# test_tangail (95).wav   0.000000  0.0  0.0  0.000000  0.107390  0.0  0.0
# test_tangail (96).wav   0.000000  0.0  0.0  0.047301  0.000000  0.0  0.0
# test_tangail (97).wav   0.000000  0.0  0.0  0.044219  0.000000  0.0  0.0
# test_tangail (98).wav   0.000000  0.0  0.0  0.119089  0.053280  0.0  0.0
# test_tangail (99).wav   0.000000  0.0  0.0  0.057071  0.000000  0.0  0.0
#
#                               য়ে   য়ো
# file_name
# test_tangail (1).wav    0.076518  0.0
# test_tangail (10).wav   0.000000  0.0
# test_tangail (100).wav  0.000000  0.0
# test_tangail (101).wav  0.058673  0.0
# test_tangail (102).wav  0.000000  0.0
# ...                          ...  ...
# test_tangail (95).wav   0.000000  0.0
# test_tangail (96).wav   0.000000  0.0
# test_tangail (97).wav   0.000000  0.0
# test_tangail (98).wav   0.000000  0.0
# test_tangail (99).wav   0.000000  0.0
#
# [132 rows x 368 columns]

# %%
term_importance = district_tfidf_results['tangail'].sum().sort_values(ascending=False)
term_importance.head(30)
# Out:
#       80.075979
# ই     18.824218
# র     16.196785
# ন     10.983273
# ক     8.246258
# অ     7.942009
# স     7.731084
# য়া    7.440627
# রা    6.991385
# ব     6.963656
# রে    6.620654
# আ     6.551499
# এ     6.394409
# ডা    6.334158
# ও     6.218542
# ম     6.038599
# লা    6.037411
# হ     5.972066
# কা    5.802546
# লো    5.628912
# সা    5.509044
# ছে    5.495410
# বা    5.462469
# না    5.458019
# য়     5.347574
# দে    5.243087
# নে    5.178321
# মা    4.974375
# উ     4.919558
# ছি    4.824602
# dtype: float64

# %%
import pandas as pd

def get_top_n_tfidf(district_tfidf_results, top_n=50):
    all_words = []

    for district, tfidf_df in district_tfidf_results.items():
        sorted_tfidf = tfidf_df.sum(axis=0).sort_values(ascending=False)
        top_n_words = sorted_tfidf.head(top_n)

        for word, score in top_n_words.items():
            all_words.append({"word": word, "score": score, "district": district})

    words_df = pd.DataFrame(all_words)

    return words_df

words_df = get_top_n_tfidf(district_tfidf_results, top_n=50)

for district, group_df in words_df.groupby('district'):
    file_name = f"{district}_grapheme_top_tfidf.csv"
    group_df.to_csv(file_name, index=False)
    print(f"Saved CSV for district: {district}")
# Out:
# Saved CSV for district: barishal
# Saved CSV for district: chittagong
# Saved CSV for district: habiganj
# Saved CSV for district: kishoreganj
# Saved CSV for district: narail
# Saved CSV for district: narsingdi
# Saved CSV for district: rangpur
# Saved CSV for district: sandwip
# Saved CSV for district: sylhet
# Saved CSV for district: tangail
